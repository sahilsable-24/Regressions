# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Position_Salaries.csv")
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = data.iloc[:,1:-1].values
y = data.iloc[:,-1:].values

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state=1)
reg.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
reg.predict([[6.5]])
# Out:
# array([150000.])

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(-1,1)
plt.scatter(X,y, color='blue')
plt.plot(X_grid, reg.predict(X_grid), color='red')
plt.title("Level VS Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_14824\3039616318.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
